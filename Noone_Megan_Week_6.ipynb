# %%
import bqplot
import numpy as np
import ipywidgets

data = np.random.random( (10, 10) )
col_sc = bqplot.ColorScale(scheme="plasma")
x_sc = bqplot.OrdinalScale()
y_sc = bqplot.OrdinalScale()
ax_col = bqplot.ColorAxis(scale = col_sc, orientation='vertical', side='right') 
ax_x = bqplot.Axis(scale = x_sc)
ax_y = bqplot.Axis(scale = y_sc, orientation='vertical')
heat_map = bqplot.GridHeatMap(color = data, scales = {'color':col_sc, 'row':y_sc, 'column':x_sc},
                             interactions={'click':'select'},
                             anchor_style={'fill':'green'},
                             selected_style={'opacity':1.0},
                             unselected_style={'opacity':0.75})
fig = bqplot.Figure(marks = [heat_map], axes=[ax_col, ax_x, ax_y])
fig
# Out:
# Figure(axes=[ColorAxis(orientation='vertical', scale=ColorScale(scheme='plasma'), side='right'), Axis(scale=Or…
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:766, in Widget._handle_msg(self, msg)
#     764         if 'buffer_paths' in data:
#     765             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 766         self.set_state(state)
#     768 # Handle a state request.
#     769 elif method == 'request_state':
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:643, in Widget.set_state(self, sync_data)
#     638         self._send(msg, buffers=echo_buffers)
#     640 # The order of these context managers is important. Properties must
#     641 # be locked when the hold_trait_notification context manager is
#     642 # released and notifications are fired.
# --> 643 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     644     for name in sync_data:
#     645         if name in self.keys:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/traitlets/traitlets.py:1502, in HasTraits.hold_trait_notifications(self)
#    1500 for changes in cache.values():
#    1501     for change in changes:
# -> 1502         self.notify_change(change)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:691, in Widget.notify_change(self, change)
#     688 name = change['name']
#     689 if self.comm is not None and self.comm.kernel is not None:
#     690     # Make sure this isn't information that the front-end just sent us.
# --> 691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
#     693         self.send_state(key=name)
#     694 super().notify_change(change)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:737, in Widget._should_send_property(self, key, value)
#     734 to_json = self.trait_metadata(key, 'to_json', self._trait_to_json)
#     735 if key in self._property_lock:
#     736     # model_state, buffer_paths, buffers
# --> 737     split_value = _remove_buffers({ key: to_json(value, self)})
#     738     split_lock = _remove_buffers({ key: self._property_lock[key]})
#     739     # A roundtrip conversion through json in the comparison takes care of
#     740     # idiosyncracies of how python data structures map to json, for example
#     741     # tuples get converted to lists.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/bqplot/traits.py:177, in array_to_json(ar, obj, force_contiguous)
#     175         return [array_to_json(np.array(row), obj, force_contiguous) for row in ar]
#     176     else:
# --> 177         raise ValueError("Unsupported dtype object")
#     179 if ar.dtype.kind in ['S', 'U']:  # strings to as plain json
#     180     return ar.tolist()
#
# ValueError: Unsupported dtype object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:766, in Widget._handle_msg(self, msg)
#     764         if 'buffer_paths' in data:
#     765             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 766         self.set_state(state)
#     768 # Handle a state request.
#     769 elif method == 'request_state':
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:643, in Widget.set_state(self, sync_data)
#     638         self._send(msg, buffers=echo_buffers)
#     640 # The order of these context managers is important. Properties must
#     641 # be locked when the hold_trait_notification context manager is
#     642 # released and notifications are fired.
# --> 643 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     644     for name in sync_data:
#     645         if name in self.keys:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/traitlets/traitlets.py:1502, in HasTraits.hold_trait_notifications(self)
#    1500 for changes in cache.values():
#    1501     for change in changes:
# -> 1502         self.notify_change(change)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:691, in Widget.notify_change(self, change)
#     688 name = change['name']
#     689 if self.comm is not None and self.comm.kernel is not None:
#     690     # Make sure this isn't information that the front-end just sent us.
# --> 691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
#     693         self.send_state(key=name)
#     694 super().notify_change(change)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:737, in Widget._should_send_property(self, key, value)
#     734 to_json = self.trait_metadata(key, 'to_json', self._trait_to_json)
#     735 if key in self._property_lock:
#     736     # model_state, buffer_paths, buffers
# --> 737     split_value = _remove_buffers({ key: to_json(value, self)})
#     738     split_lock = _remove_buffers({ key: self._property_lock[key]})
#     739     # A roundtrip conversion through json in the comparison takes care of
#     740     # idiosyncracies of how python data structures map to json, for example
#     741     # tuples get converted to lists.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/bqplot/traits.py:177, in array_to_json(ar, obj, force_contiguous)
#     175         return [array_to_json(np.array(row), obj, force_contiguous) for row in ar]
#     176     else:
# --> 177         raise ValueError("Unsupported dtype object")
#     179 if ar.dtype.kind in ['S', 'U']:  # strings to as plain json
#     180     return ar.tolist()
#
# ValueError: Unsupported dtype object
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:766, in Widget._handle_msg(self, msg)
#     764         if 'buffer_paths' in data:
#     765             _put_buffers(state, data['buffer_paths'], msg['buffers'])
# --> 766         self.set_state(state)
#     768 # Handle a state request.
#     769 elif method == 'request_state':
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:643, in Widget.set_state(self, sync_data)
#     638         self._send(msg, buffers=echo_buffers)
#     640 # The order of these context managers is important. Properties must
#     641 # be locked when the hold_trait_notification context manager is
#     642 # released and notifications are fired.
# --> 643 with self._lock_property(**sync_data), self.hold_trait_notifications():
#     644     for name in sync_data:
#     645         if name in self.keys:
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/contextlib.py:144, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     142 if typ is None:
#     143     try:
# --> 144         next(self.gen)
#     145     except StopIteration:
#     146         return False
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/traitlets/traitlets.py:1502, in HasTraits.hold_trait_notifications(self)
#    1500 for changes in cache.values():
#    1501     for change in changes:
# -> 1502         self.notify_change(change)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:691, in Widget.notify_change(self, change)
#     688 name = change['name']
#     689 if self.comm is not None and self.comm.kernel is not None:
#     690     # Make sure this isn't information that the front-end just sent us.
# --> 691     if name in self.keys and self._should_send_property(name, getattr(self, name)):
#     692         # Send new state to front-end
#     693         self.send_state(key=name)
#     694 super().notify_change(change)
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/ipywidgets/widgets/widget.py:737, in Widget._should_send_property(self, key, value)
#     734 to_json = self.trait_metadata(key, 'to_json', self._trait_to_json)
#     735 if key in self._property_lock:
#     736     # model_state, buffer_paths, buffers
# --> 737     split_value = _remove_buffers({ key: to_json(value, self)})
#     738     split_lock = _remove_buffers({ key: self._property_lock[key]})
#     739     # A roundtrip conversion through json in the comparison takes care of
#     740     # idiosyncracies of how python data structures map to json, for example
#     741     # tuples get converted to lists.
#
# File /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages/bqplot/traits.py:177, in array_to_json(ar, obj, force_contiguous)
#     175         return [array_to_json(np.array(row), obj, force_contiguous) for row in ar]
#     176     else:
# --> 177         raise ValueError("Unsupported dtype object")
#     179 if ar.dtype.kind in ['S', 'U']:  # strings to as plain json
#     180     return ar.tolist()
#
# ValueError: Unsupported dtype object
